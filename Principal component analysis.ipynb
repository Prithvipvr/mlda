# %% [markdown]
# <a href="https://colab.research.google.com/github/Prithvipvr/mlda/blob/main/Principal%20component%20analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import load_iris

iris = load_iris()
y = iris.target

scalar = StandardScaler()
x_scaled = scalar.fit_transform(iris.data)

pca = PCA(n_components=2)
x_pca = pca.fit_transform(x_scaled)

plt.figure(figsize=(8,6))
plt.title('PCA pf IRIS Data')
plt.xlabel('Principal compoent 1')
plt.ylabel('Principal compoent 2')

plt.scatter(x_pca[:,0], x_pca[:,1], c=y)
plt.legend()
plt.show()
# Out:
# /tmp/ipython-input-739478163.py:22: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
